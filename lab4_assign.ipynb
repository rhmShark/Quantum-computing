# %%
#Name: Rahma Mohamed Abdo Mohamed Elsharkawy
#email: rahma.elsharkawy82005@gmail.com
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)

# Initial state
initial_sv = Statevector.from_label('000')

# %%
# Apply Hadamard gate to the first qubit
qc.h(0)
sv_after_h = initial_sv.evolve(qc)

# %%
# Apply CNOT from qubit 0 to qubit 1
qc.cx(0, 1)
sv_after_cx1 = sv_after_h.evolve(qc)

# %%
# Apply CNOT from qubit 1 to qubit 2
qc.cx(1, 2)
final_sv = sv_after_cx1.evolve(qc)

# %%
# Display final unitary operator
unitary = Operator(qc)
unitary.data
# Out:
# array([[ 0.70710678+0.j,  0.70710678+0.j,  0.        +0.j,
#          0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
#         -0.70710678+0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.70710678+0.j,  0.70710678+0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.70710678+0.j, -0.70710678+0.j,
#          0.        +0.j,  0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.70710678+0.j,  0.70710678+0.j,
#          0.        +0.j,  0.        +0.j],
#        [ 0.        +0.j,  0.        +0.j,  0.        +0.j,
#          0.        +0.j,  0.        +0.j,  0.        +0.j,
# ...

# %%
# Draw the circuit
qc.draw('mpl')

# %%
# Simulate and display histogram
sim = Aer.get_backend('qasm_simulator')
qc.measure_all()
qobj = assemble(transpile(qc, sim))
result = sim.run(qobj).result()
counts = result.get_counts()

# Plot histogram
plot_histogram(counts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Simulate and display histogram
# ----> 2 sim = Aer.get_backend('qasm_simulator')
#       3 qc.measure_all()
#       4 qobj = assemble(transpile(qc, sim))
#
# NameError: name 'Aer' is not defined
